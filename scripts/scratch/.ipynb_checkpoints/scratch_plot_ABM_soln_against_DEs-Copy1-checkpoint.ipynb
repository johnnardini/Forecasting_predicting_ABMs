# %%
import sys
sys.path.append('../../')
import numpy as np
import matplotlib.pyplot as plt
import pdb
import matplotlib as mpl

from src.ABM_package import cell_interaction_ABM, migration_step_pulling, migration_step_adhesion

from src.DE_simulation import fickian_diffusion, Diffusion_eqn, simple_pulling_diffusion, simple_adhesion_diffusion,logistic_proliferation, Reaction_Diffusion_eqn
from scipy.integrate import odeint

np.random.seed(42)

# %%
Pp = 0.0
Pm = 0.5
Ppull = 0.5

C_out ,t_out, x_out, plot_list = cell_interaction_ABM((Pm, Ppull),
                                                      interaction_rate_function = migration_step_pulling,
                                                      T_end=1000.0)

C = C_out
t = t_out
x = x_out

## Mean-field model
q = [Pm/4,Ppull]
IC = C[:,0]
sol = odeint(Diffusion_eqn, IC, t, args=(x, q, simple_pulling_diffusion))
sol = sol.T    

for i in np.arange(0,100,20):

    plt.figure()
    plt.plot(x, C[:,i])
    plt.plot(x, sol[:,i],"r--",linewidth=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 5>()
#       2 Pm = 0.5
#       3 Ppull = 0.5
#       5 C_out ,t_out, x_out, plot_list = cell_interaction_ABM((Pm, Ppull),
# ----> 6                                                       interaction_rate_function = test_migration_step_pulling,
#       7                                                       T_end=1000.0)
#       9 C = C_out
#      10 t = t_out
#
# NameError: name 'test_migration_step_pulling' is not defined

# %%
Pp = 0.0
Pm = 0.5
Padh = 0.25

C_out ,t_out, x_out, plot_list = cell_interaction_ABM((Pm, Pp, Padh),
                                                      interaction_rate_function = test_migration_step_adhesion,
                                                      T_end=1000.0)

C = C_out
t = t_out
x = x_out

## Mean-field model
q = [Pm/4,Padh]
IC = C[:,0]
sol = odeint(Diffusion_eqn, IC, t, args=(x, q, simple_adhesion_diffusion))
sol = sol.T    

for i in np.arange(0,100,20):

    plt.figure()
    plt.plot(x, C[:,i])
    plt.plot(x, sol[:,i],"r--",linewidth=2)
